# %%
# !pip install langchain_core

# %%
from langchain_core.prompts import PromptTemplate
prompt_template = PromptTemplate.from_template(
    "Tell me a {adjective} joke about {content}."
)

prompt_template.format(adjective="funny", content="chickens")
# Out:
# 'Tell me a funny joke about chickens.'

# %% [markdown]
# # Language Model

# %%
# !pip install ibm-watson-machine-learning

# %% [markdown]
# Note that the ibm-watson-machine-learning package is currently in deprecation mode and is recommended to migrate to the ibm-watsonx-ai package for enhanced functionalities.
# 2

# %%
from ibm_watson_machine_learning.foundation_models.utils.enums import ModelTypes, DecodingMethods
from ibm_watson_machine_learning.foundation_models.inference import ModelInference
from ibm_watson_machine_learning.metanames import GenTextParamsMetaNames as GenParams

# %%
model_id = 'mistralai/mixtral-8x7b-instruct-v01'

parameters = {
    GenParams.MAX_NEW_TOKENS: 256,
    # this controls the maximum number of tokens in generated output
    GenParams.TEMPERATURE: 0.5
    # this randomness or creativity of the model's responses
}

credentials = { "url": "https://us-south.ml.cloud.ibm.com"}

project_id = "skills-network"

model = ModelInference(model_id=model_id, params=parameters, credentials=credentials, project_id=project_id)

msg = model.generate("In today's sales meeting, we ")

print(msg['results'][0]['generated_text'])
# Out:
# WARNING:ibm_watson_machine_learning.wml_client_error:'`apikey` for IAM token is not provided in credentials for the client'
# ---------------------------------------------------------------------------
# WMLClientError                            Traceback (most recent call last)
# /tmp/ipython-input-4012943036.py in <cell line: 0>()
#      12 project_id = "skills-network"
#      13
# ---> 14 model = ModelInference(model_id=model_id, params=parameters, credentials=credentials, project_id=project_id)
#
# /usr/local/lib/python3.12/dist-packages/ibm_watson_machine_learning/foundation_models/inference/model_inference.py in __init__(self, model_id, deployment_id, params, credentials, project_id, space_id, verify, api_client)
#     128
#     129         if credentials:
# --> 130             self._client = APIClient(credentials, verify=verify)
#     131         elif api_client:
#     132             self._client = api_client
#
# ...
